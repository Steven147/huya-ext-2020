# %% [markdown]
# 在/miniapp/examples/game-common-demo-a/server-python/src目录下运行main.py
#
# 必须停止上一次运行，才能进行下一次运行

# %%
# !python main.py
# Out:
# HUYA_APPID:4e7d7f42cad63759
# server start
# [2020-07-24 19:35:42 +0800] [19395] [INFO] Goin' Fast @ http://0.0.0.0:9090
# [2020-07-24 19:35:42,031] 19395-INFO app::_helper():l1386: Goin' Fast @ http://0.0.0.0:9090
# [2020-07-24 19:35:42 +0800] [19395] [INFO] Starting worker [19395]
# [2020-07-24 19:35:42,035] 19395-INFO server::serve():l906: Starting worker [19395]
# [2020-07-24 19:35:52,165] 19395-DEBUG protocol::__init__():l244: undefined - state = CONNECTING
# [2020-07-24 19:35:52,165] 19395-DEBUG protocol::connection_made():l1340: server - event = connection_made(<TCPTransport closed=False reading=True 0x556d3e05ff28>)
# [2020-07-24 19:35:52,165] 19395-DEBUG protocol::connection_open():l330: server - state = OPEN
# ...
